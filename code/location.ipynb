# %%
import pandas as pd
from datetime import datetime 
import time

# %%
data = pd.read_csv('df_final_161_170.csv')
# data0 = pd.read_csv("tps2_180.csv")
# data1 = pd.read_csv("tps2_181.csv")
# data2 = pd.read_csv("tps2_182.csv")
# data3 = pd.read_csv("tps2_183.csv")
# data4 = pd.read_csv("tps2_184.csv")
# data5 = pd.read_csv("tps2_185.csv")
# Out:
# D:\anaconda\conda\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# data =pd.concat([data0, data1, data2, data3, data4, data5],sort = False)

# %%
data
# Out:
#          Unnamed: 0 Unnamed: 0.1 Building    Level      ClientMacAddr  \
# 0                 0            0     TPS2  Level 3  68:c4:4d:80:2e:45
# 1                 1            2     TPS2  Level 3  70:fd:46:8f:72:22
# 2                 2            6     TPS2  Level 3  f0:d7:aa:bb:36:6f
# 3                 3           16     TPS2  Level 3  9c:f4:8e:4a:95:81
# 4                 4           18     TPS2  Level 3  98:39:8e:72:e5:d3
# ...             ...          ...      ...      ...                ...
# 7414755      794190      1757330     TPS2  Level 3  68:7d:6b:2d:22:c1
# 7414756      794191      1757332     TPS2  Level 3  40:98:ad:51:3c:8c
# 7414757      794192      1757334     TPS2  Level 3  9c:4f:da:6f:ca:90
# 7414758      794193      1757336     TPS2  Level 3  04:1b:6d:ad:d3:fe
# 7414759      794194      1757337     TPS2  Level 3  04:1b:6d:ad:d3:fe
#
#              lat      lng                localtime
# 0       -22.8134 -43.2475  2019-11-10 19:53:51.099
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7414760 entries, 0 to 7414759
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Unnamed: 0     int64
#  1   Unnamed: 0.1   object
#  2   Building       object
#  3   Level          object
#  4   ClientMacAddr  object
#  5   lat            object
#  6   lng            object
#  7   localtime      object
# dtypes: int64(1), object(7)
# memory usage: 452.6+ MB

# %%
data1 = data.drop(['Unnamed: 0','Unnamed: 0.1'],axis = 1)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7414760 entries, 0 to 7414759
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Building       object
#  1   Level          object
#  2   ClientMacAddr  object
#  3   lat            object
#  4   lng            object
#  5   localtime      object
# dtypes: object(6)
# memory usage: 339.4+ MB

# %%
data1 = data1.dropna()

# %%
data1.head()
# Out:
#   Building    Level      ClientMacAddr      lat      lng  \
# 0     TPS2  Level 3  68:c4:4d:80:2e:45 -22.8134 -43.2475
# 1     TPS2  Level 3  70:fd:46:8f:72:22 -22.8153 -43.2464
# 2     TPS2  Level 3  f0:d7:aa:bb:36:6f  -22.814 -43.2472
# 3     TPS2  Level 3  9c:f4:8e:4a:95:81 -22.8152 -43.2469
# 4     TPS2  Level 3  98:39:8e:72:e5:d3 -22.8149 -43.2469
#
#                  localtime
# 0  2019-11-10 19:53:51.099
# 1  2019-11-10 19:53:51.511
# 2  2019-11-10 19:53:51.593
# 3  2019-11-10 19:53:52.413
# 4  2019-11-10 19:53:52.414

# %%
data1[['lat','lng']] = data1[['lat','lng']].apply(pd.to_numeric, errors = 'coerce')

# %%
# data_international = data[(data["lat"] >  -22.815522) & (data["lat"]< -22.815151) & (data.lng > -43.245908) & (data.lng < -43.245545)]

# %%
# data_international["datetime"] = pd.to_datetime(data_international["localtime"])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# data_international
# Out:
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 29             136     TPS2  10:b1:f8:0d:b7:0b  Level 3 -22.815210 -43.245629
# 82             456     TPS2  98:00:c6:5e:9e:3b  Level 3 -22.815161 -43.245731
# 115            590     TPS2  0c:cb:85:c3:db:17  Level 3 -22.815388 -43.245742
# 190            846     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# 192            850     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# ...            ...      ...                ...      ...        ...        ...
# 443334     1849721     TPS2  38:9a:f6:31:77:8d  Level 3 -22.815401 -43.245558
# 443335     1849722     TPS2  38:9a:f6:31:77:8d  Level 3 -22.815401 -43.245558
# 443345     1849785     TPS2  fc:64:3a:1f:2f:2a  Level 3 -22.815482 -43.245621
# 443410     1850100     TPS2  68:c4:4d:42:f5:fb  Level 3 -22.815359 -43.245628
# 443425     1850216     TPS2  fc:64:3a:1f:2f:2a  Level 3 -22.815354 -43.245594
#
# ...

# %%
data_domestic =  data1[(data1["lat"] > -22.814515) & (data1["lat"]< -22.814147) & (data1.lng >-43.247567) & (data1.lng < -43.247118)]

# %%
data_domestic["datetime"] = pd.to_datetime(data_domestic["localtime"])
# Out:
# D:\anaconda\conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_domestic.ClientMacAddr.value_counts()
# Out:
# 28:83:35:25:74:6d    1392
# bc:e2:65:98:8e:df     768
# 5c:c9:d3:20:18:5a     736
# 0c:cb:85:3b:cb:46     672
# a8:16:d0:c5:5d:11     648
#                      ...
# 30:4b:07:c0:c9:25       1
# f0:d7:aa:f2:67:ed       1
# 08:c5:e1:8e:45:a0       1
# 64:a5:c3:b0:20:4b       1
# fc:42:03:8d:04:f9       1
# Name: ClientMacAddr, Length: 36755, dtype: int64

# %%
data_domestic
# Out:
#         Building    Level      ClientMacAddr        lat        lng  \
# 79          TPS2  Level 3  20:32:6c:61:9f:86 -22.814209 -43.247272
# 202         TPS2  Level 3  20:32:6c:61:9f:86 -22.814159 -43.247406
# 212         TPS2  Level 3  64:c2:de:17:04:3a -22.814211 -43.247217
# 225         TPS2  Level 3  7c:03:ab:8d:71:c9 -22.814342 -43.247437
# 227         TPS2  Level 3  08:c5:e1:ee:44:f4 -22.814475 -43.247208
# ...          ...      ...                ...        ...        ...
# 7414592     TPS2  Level 3  c0:8c:71:33:71:74 -22.814270 -43.247348
# 7414628     TPS2  Level 3  f4:c2:48:08:80:29 -22.814427 -43.247273
# 7414676     TPS2  Level 3  28:6a:ba:d6:13:e9 -22.814211 -43.247170
# 7414693     TPS2  Level 3  a8:16:d0:9a:06:77 -22.814150 -43.247313
# 7414699     TPS2  Level 3  9c:2a:83:41:1b:9d -22.814454 -43.247532
#
#                        localtime                datetime
# 79        2019-11-10 19:54:13.74 2019-11-10 19:54:13.740
# ...

# %%
data_domestic = data_domestic.reset_index(drop = True)

# %%
data_domestic.columns
# Out:
# Index(['Building', 'Level', 'ClientMacAddr', 'lat', 'lng', 'localtime',
#        'datetime'],
#       dtype='object')

# %%
data_domestic.to_csv('data_domestic.csv')

# %%
# data_exp = data_international[(data_international.datetime > '2019-11-15 13:49:44.346000') & (data_international.datetime < '2019-11-15 18:49:44.346000') ]

# %%
# data_exp
# Out:
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 82             456     TPS2  98:00:c6:5e:9e:3b  Level 3 -22.815161 -43.245731
# 115            590     TPS2  0c:cb:85:c3:db:17  Level 3 -22.815388 -43.245742
# 190            846     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# 192            850     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# 211            922     TPS2  70:fd:46:a9:a1:a0  Level 3 -22.815279 -43.245828
# ...            ...      ...                ...      ...        ...        ...
# 125593      454760     TPS2  28:83:35:e4:5d:2b  Level 3 -22.815184 -43.245669
# 125609      454820     TPS2  a8:db:03:16:23:9e  Level 3 -22.815389 -43.245795
# 125638      454932     TPS2  7c:89:56:aa:a1:bc  Level 3 -22.815326 -43.245603
# 125639      454933     TPS2  7c:89:56:aa:a1:bc  Level 3 -22.815326 -43.245603
# 125661      455014     TPS2  b0:10:41:15:5c:80  Level 3 -22.815283 -43.245655
#
# ...

# %%
# data_exp.iloc[0,7]
# Out:
# Timestamp('2019-11-15 13:49:57.439000')

# %%
data_exp["waiting_time"] = data_exp["datetime"].max()-data_exp["datetime"].min()
data_exp
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 82             456     TPS2  98:00:c6:5e:9e:3b  Level 3 -22.815161 -43.245731
# 115            590     TPS2  0c:cb:85:c3:db:17  Level 3 -22.815388 -43.245742
# 190            846     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# 192            850     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# 211            922     TPS2  70:fd:46:a9:a1:a0  Level 3 -22.815279 -43.245828
# ...            ...      ...                ...      ...        ...        ...
# ...

# %%
for i in range(0,4053):
    data_temp = data_exp[data_exp.ClientMacAddr == data_exp.iloc[i,2]]
    data_exp.iloc[i,8] = data_temp["datetime"].max() - data_temp["datetime"].min()
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
data_international["waiting_time"] = data_international["datetime"].max()-data_international["datetime"].min()
data_international
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 29             136     TPS2  10:b1:f8:0d:b7:0b  Level 3 -22.815210 -43.245629
# 82             456     TPS2  98:00:c6:5e:9e:3b  Level 3 -22.815161 -43.245731
# 115            590     TPS2  0c:cb:85:c3:db:17  Level 3 -22.815388 -43.245742
# 190            846     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# 192            850     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# ...            ...      ...                ...      ...        ...        ...
# ...

# %%
for i in range(0,86720):
    data_temp = data_international[data_international.ClientMacAddr == data_international.iloc[i,2]]
    data_international.iloc[i,8] = data_temp["datetime"].max() - data_temp["datetime"].min()

# %%
data_domestic["waiting_time"] = data_domestic["datetime"].max()-data_domestic["datetime"].min()
data_domestic
# Out:
# D:\anaconda\conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Building    Level      ClientMacAddr        lat        lng  \
# 79          TPS2  Level 3  20:32:6c:61:9f:86 -22.814209 -43.247272
# 202         TPS2  Level 3  20:32:6c:61:9f:86 -22.814159 -43.247406
# 212         TPS2  Level 3  64:c2:de:17:04:3a -22.814211 -43.247217
# 225         TPS2  Level 3  7c:03:ab:8d:71:c9 -22.814342 -43.247437
# 227         TPS2  Level 3  08:c5:e1:ee:44:f4 -22.814475 -43.247208
# ...          ...      ...                ...        ...        ...
# 7414592     TPS2  Level 3  c0:8c:71:33:71:74 -22.814270 -43.247348
# ...

# %%
for i in range(0,119505):
    data_temp = data_domestic[data_domestic.ClientMacAddr == data_domestic.iloc[i,2]]
    data_domestic.iloc[i,8] = data_temp["datetime"].max() - data_temp["datetime"].min()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-0d4cd7f1be12> in <module>
#       1 for i in range(0,119505):
#       2     data_temp = data_domestic[data_domestic.ClientMacAddr == data_domestic.iloc[i,2]]
# ----> 3     data_domestic.iloc[i,8] = data_temp["datetime"].max() - data_temp["datetime"].min()
#
# D:\anaconda\conda\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668         else:
#     669             key = com.apply_if_callable(key, self.obj)
# --> 670         indexer = self._get_setitem_indexer(key)
#     671         self._setitem_with_indexer(indexer, value)
#     672
#
# D:\anaconda\conda\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     646         if isinstance(key, tuple):
#     647             try:
# --> 648                 return self._convert_tuple(key)
# ...

# %%
data_domestic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119505 entries, 23 to 443455
# Data columns (total 9 columns):
# Unnamed: 0       119505 non-null int64
# Building         119505 non-null object
# ClientMacAddr    119505 non-null object
# Level            119505 non-null object
# lat              119505 non-null float64
# lng              119505 non-null float64
# localtime        119505 non-null object
# datetime         119505 non-null datetime64[ns]
# waiting_time     119505 non-null timedelta64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4), timedelta64[ns](1)
# memory usage: 14.1+ MB

# %%
data_domestic
# Out:
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 23             110     TPS2  c0:8c:71:70:f4:85  Level 3 -22.814361 -43.247444
# 27             126     TPS2  48:c7:96:88:7b:e9  Level 3 -22.814421 -43.247552
# 35             170     TPS2  60:ab:67:93:af:30  Level 3 -22.814456 -43.247440
# 51             254     TPS2  10:f1:f2:9a:67:5e  Level 3 -22.814349 -43.247505
# 59             302     TPS2  24:18:1d:c9:46:86  Level 3 -22.814215 -43.247342
# ...            ...      ...                ...      ...        ...        ...
# 443306     1849583     TPS2  70:fd:46:78:82:9a  Level 3 -22.814505 -43.247494
# 443436     1850288     TPS2  30:07:4d:a4:e3:20  Level 3 -22.814390 -43.247548
# 443440     1850310     TPS2  aa:16:d0:c5:f0:65  Level 3 -22.814252 -43.247351
# 443441     1850311     TPS2  aa:16:d0:c5:f0:65  Level 3 -22.814252 -43.247351
# 443455     1850386     TPS2  98:ca:33:dd:33:91  Level 3 -22.814172 -43.247504
#
# ...

# %%
data_domestic["waiting_time"]=data_domestic["waiting_time"].dt.total_seconds()
data_domestic["waiting_time"]=data_domestic["waiting_time"]/60
data_domestic.to_csv("domestic_TPS2.csv")
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_domestic
# Out:
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 23             110     TPS2  c0:8c:71:70:f4:85  Level 3 -22.814361 -43.247444
# 27             126     TPS2  48:c7:96:88:7b:e9  Level 3 -22.814421 -43.247552
# 35             170     TPS2  60:ab:67:93:af:30  Level 3 -22.814456 -43.247440
# 51             254     TPS2  10:f1:f2:9a:67:5e  Level 3 -22.814349 -43.247505
# 59             302     TPS2  24:18:1d:c9:46:86  Level 3 -22.814215 -43.247342
# ...            ...      ...                ...      ...        ...        ...
# 443306     1849583     TPS2  70:fd:46:78:82:9a  Level 3 -22.814505 -43.247494
# 443436     1850288     TPS2  30:07:4d:a4:e3:20  Level 3 -22.814390 -43.247548
# 443440     1850310     TPS2  aa:16:d0:c5:f0:65  Level 3 -22.814252 -43.247351
# 443441     1850311     TPS2  aa:16:d0:c5:f0:65  Level 3 -22.814252 -43.247351
# 443455     1850386     TPS2  98:ca:33:dd:33:91  Level 3 -22.814172 -43.247504
#
# ...

# %%
data_international["waiting_time"]=data_international["waiting_time"].dt.total_seconds()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_international["waiting_time"]=data_international["waiting_time"]/60
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_international
# Out:
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 29             136     TPS2  10:b1:f8:0d:b7:0b  Level 3 -22.815210 -43.245629
# 82             456     TPS2  98:00:c6:5e:9e:3b  Level 3 -22.815161 -43.245731
# 115            590     TPS2  0c:cb:85:c3:db:17  Level 3 -22.815388 -43.245742
# 190            846     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# 192            850     TPS2  bc:a5:8b:b1:43:f3  Level 3 -22.815282 -43.245723
# ...            ...      ...                ...      ...        ...        ...
# 443334     1849721     TPS2  38:9a:f6:31:77:8d  Level 3 -22.815401 -43.245558
# 443335     1849722     TPS2  38:9a:f6:31:77:8d  Level 3 -22.815401 -43.245558
# 443345     1849785     TPS2  fc:64:3a:1f:2f:2a  Level 3 -22.815482 -43.245621
# 443410     1850100     TPS2  68:c4:4d:42:f5:fb  Level 3 -22.815359 -43.245628
# 443425     1850216     TPS2  fc:64:3a:1f:2f:2a  Level 3 -22.815354 -43.245594
#
# ...

# %%
data_international.to_csv("international_TPS2.csv")

# %%
data_exp[data_exp.datetime == '2019-11-29 13:09:35.630000']
# Out:
#         Unnamed: 0 Building      ClientMacAddr    Level        lat        lng  \
# 347415     1481750     TPS2  d4:c9:4b:57:4e:de  Level 3 -22.815321 -43.245853
#
#                      localtime                datetime
# 347415  2019-11-29 13:09:35.63 2019-11-29 13:09:35.630

# %%
data5 = pd.read_csv("rio05.csv")

# %%
data555 = data5[(data5["lat"] > -22.811060900) & (data5["lat"]< -22.810949671) & (data5.lng >-43.2522959488) & (data5.lng <-43.2522223556)]

# %%
data555
# Out:
#        Building    Level      ClientMacAddr        lat        lng  \
# 16150      TPS1  Level 3  ac:5f:3e:96:28:e5 -22.811027 -43.252232
# 16151      TPS1  Level 3  ac:5f:3e:96:28:e5 -22.811027 -43.252232
# 17912      TPS1  Level 3  60:1d:91:e7:4a:a0 -22.810975 -43.252227
# 17913      TPS1  Level 3  60:1d:91:e7:4a:a0 -22.810975 -43.252227
# 41184      TPS1  Level 3  7a:b4:7b:da:cc:74 -22.811008 -43.252222
# ...         ...      ...                ...        ...        ...
# 555902     TPS1  Level 3  30:4b:07:0f:ec:3d -22.810981 -43.252225
# 558014     TPS1  Level 3  80:82:23:49:1b:44 -22.810955 -43.252228
# 558015     TPS1  Level 3  80:82:23:49:1b:44 -22.810955 -43.252228
# 563481     TPS1  Level 3  38:9a:f6:26:9d:fb -22.810959 -43.252252
# 563488     TPS1  Level 3  38:9a:f6:26:9d:fb -22.810969 -43.252238
#
#                           localtime
# 16150   2019-08-27 12:49:19.786 UTC
# 16151   2019-08-27 12:49:19.786 UTC
# 17912     2019-08-27 13:59:23.5 UTC
# ...

# %%
data55 =  data5[(data5["lat"] > -22.811457270) & (data5["lat"]< -22.811349129) & (data5.lng >-43.252007459) & (data5.lng < -43.251896223)]

# %%
data55
# Out:
#        Building    Level      ClientMacAddr        lat        lng  \
# 9186       TPS1  Level 3  d0:a6:37:8d:ad:2f -22.811457 -43.251906
# 9187       TPS1  Level 3  d0:a6:37:8d:ad:2f -22.811457 -43.251906
# 16570      TPS1  Level 3  38:80:df:6f:39:e3 -22.811356 -43.251916
# 16571      TPS1  Level 3  38:80:df:6f:39:e3 -22.811356 -43.251916
# 42778      TPS1  Level 3  48:49:c7:c8:8f:ee -22.811371 -43.251972
# ...         ...      ...                ...        ...        ...
# 549872     TPS1  Level 3  a8:96:75:ce:65:96 -22.811368 -43.251944
# 549873     TPS1  Level 3  a8:96:75:ce:65:96 -22.811368 -43.251944
# 555364     TPS1  Level 3  40:b0:76:82:80:07 -22.811369 -43.251919
# 562035     TPS1  Level 3  10:98:c3:13:61:35 -22.811423 -43.251915
# 566447     TPS1  Level 3  34:bb:26:af:f2:e8 -22.811395 -43.251911
#
#                           localtime
# 9186    2019-08-27 09:20:12.926 UTC
# 9187    2019-08-27 09:20:12.926 UTC
# 16570   2019-08-27 13:04:07.957 UTC
# ...

# %%
domestics = pd.concat([data44,data55])

# %%
domestics
# Out:
#         Building    Level      ClientMacAddr        lat        lng  \
# 1361520     TPS1  Level 3  48:60:5f:72:22:df -22.811380 -43.251905
# 1361521     TPS1  Level 3  48:60:5f:72:22:df -22.811380 -43.251905
# 1364686     TPS1  Level 3  48:49:c7:cf:39:d4 -22.811387 -43.251929
# 1364687     TPS1  Level 3  48:49:c7:cf:39:d4 -22.811387 -43.251929
# 1369982     TPS1  Level 3  30:cb:f8:96:0d:7e -22.811405 -43.251908
# ...          ...      ...                ...        ...        ...
# 549872      TPS1  Level 3  a8:96:75:ce:65:96 -22.811368 -43.251944
# 549873      TPS1  Level 3  a8:96:75:ce:65:96 -22.811368 -43.251944
# 555364      TPS1  Level 3  40:b0:76:82:80:07 -22.811369 -43.251919
# 562035      TPS1  Level 3  10:98:c3:13:61:35 -22.811423 -43.251915
# 566447      TPS1  Level 3  34:bb:26:af:f2:e8 -22.811395 -43.251911
#
#                            localtime
# 1361520  2019-08-01 04:34:56.245 UTC
# 1361521  2019-08-01 04:34:56.245 UTC
# 1364686  2019-08-01 05:30:14.337 UTC
# ...

# %%
international = pd.concat([data444, data555])

# %%
international
# Out:
#         Building    Level      ClientMacAddr        lat        lng  \
# 1359456     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810985 -43.252243
# 1359457     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810985 -43.252243
# 1362572     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810975 -43.252267
# 1362573     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810975 -43.252267
# 1364336     TPS1  Level 3  c0:bd:d1:f5:bb:c6 -22.810997 -43.252239
# ...          ...      ...                ...        ...        ...
# 555902      TPS1  Level 3  30:4b:07:0f:ec:3d -22.810981 -43.252225
# 558014      TPS1  Level 3  80:82:23:49:1b:44 -22.810955 -43.252228
# 558015      TPS1  Level 3  80:82:23:49:1b:44 -22.810955 -43.252228
# 563481      TPS1  Level 3  38:9a:f6:26:9d:fb -22.810959 -43.252252
# 563488      TPS1  Level 3  38:9a:f6:26:9d:fb -22.810969 -43.252238
#
#                            localtime
# 1359456  2019-08-01 04:05:03.337 UTC
# 1359457  2019-08-01 04:05:03.337 UTC
# 1362572   2019-08-01 04:55:50.47 UTC
# ...

# %%
domestics["datetime"] = pd.to_datetime(domestics["localtime"])

# %%
domestics
# Out:
#         Building    Level      ClientMacAddr        lat        lng  \
# 1361520     TPS1  Level 3  48:60:5f:72:22:df -22.811380 -43.251905
# 1361521     TPS1  Level 3  48:60:5f:72:22:df -22.811380 -43.251905
# 1364686     TPS1  Level 3  48:49:c7:cf:39:d4 -22.811387 -43.251929
# 1364687     TPS1  Level 3  48:49:c7:cf:39:d4 -22.811387 -43.251929
# 1369982     TPS1  Level 3  30:cb:f8:96:0d:7e -22.811405 -43.251908
# ...          ...      ...                ...        ...        ...
# 549872      TPS1  Level 3  a8:96:75:ce:65:96 -22.811368 -43.251944
# 549873      TPS1  Level 3  a8:96:75:ce:65:96 -22.811368 -43.251944
# 555364      TPS1  Level 3  40:b0:76:82:80:07 -22.811369 -43.251919
# 562035      TPS1  Level 3  10:98:c3:13:61:35 -22.811423 -43.251915
# 566447      TPS1  Level 3  34:bb:26:af:f2:e8 -22.811395 -43.251911
#
#                            localtime                         datetime
# 1361520  2019-08-01 04:34:56.245 UTC 2019-08-01 04:34:56.245000+00:00
# ...

# %%
domestics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 1361520 to 566447
# Data columns (total 7 columns):
# Building         994 non-null object
# Level            994 non-null object
# ClientMacAddr    994 non-null object
# lat              994 non-null float64
# lng              994 non-null float64
# localtime        994 non-null object
# datetime         994 non-null datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(2), object(4)
# memory usage: 62.1+ KB

# %%
domestics.to_csv("domestics.csv")

# %%
international["datetime"] = pd.to_datetime(international["localtime"])

# %%
international
# Out:
#         Building    Level      ClientMacAddr        lat        lng  \
# 1359456     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810985 -43.252243
# 1359457     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810985 -43.252243
# 1362572     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810975 -43.252267
# 1362573     TPS1  Level 3  c2:9f:db:97:5d:fe -22.810975 -43.252267
# 1364336     TPS1  Level 3  c0:bd:d1:f5:bb:c6 -22.810997 -43.252239
# ...          ...      ...                ...        ...        ...
# 555902      TPS1  Level 3  30:4b:07:0f:ec:3d -22.810981 -43.252225
# 558014      TPS1  Level 3  80:82:23:49:1b:44 -22.810955 -43.252228
# 558015      TPS1  Level 3  80:82:23:49:1b:44 -22.810955 -43.252228
# 563481      TPS1  Level 3  38:9a:f6:26:9d:fb -22.810959 -43.252252
# 563488      TPS1  Level 3  38:9a:f6:26:9d:fb -22.810969 -43.252238
#
#                            localtime                         datetime
# 1359456  2019-08-01 04:05:03.337 UTC 2019-08-01 04:05:03.337000+00:00
# ...

# %%
international.to_csv("international.csv")

# %%
data1 = pd.read_csv("rio01.csv")

# %%
data1
# Out:
#         Building    Level      ClientMacAddr        lat        lng  \
# 0           TPS1  Level 2  e0:37:bf:da:68:b0 -22.812075 -43.250576
# 1           TPS1  Level 2  e0:37:bf:da:68:b0 -22.812075 -43.250576
# 2           TPS1  Level 2  c8:3c:85:52:d0:83 -22.811972 -43.250098
# 3           TPS1  Level 2  c8:3c:85:52:d0:83 -22.811972 -43.250098
# 4           TPS1  Level 2  fc:64:3a:81:1a:3c -22.811866 -43.251192
# ...          ...      ...                ...        ...        ...
# 2569844     TPS1  Level 2  ea:79:35:46:4a:64 -22.812101 -43.250800
# 2569845     TPS1  Level 2  d4:63:c6:e9:df:14 -22.811746 -43.249913
# 2569846     TPS1  Level 2  d4:63:c6:e9:df:14 -22.811746 -43.249913
# 2569847     TPS1  Level 2  8c:f7:10:76:02:70 -22.811892 -43.251813
# 2569848     TPS1  Level 2  8c:f7:10:76:02:70 -22.811892 -43.251813
#
#                            localtime
# 0        2019-08-25 10:21:02.543 UTC
# 1        2019-08-25 10:21:02.543 UTC
# 2        2019-08-25 10:21:02.555 UTC
# ...

# %%
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
data111 = data1[(data1["lat"] > -22.811060900) & (data1["lat"]< -22.810949671) & (data1.lng >-43.2522959488) & (data1.lng <-43.2522223556)]

# %%
data111
# Out:
# Empty DataFrame
# Columns: [Building, Level, ClientMacAddr, lat, lng, localtime]
# Index: []

# %%
a = data4.ClientMacAddr.value_counts()

# %%
a[:50]
# Out:
# c0:25:e9:7e:d8:5c    249122
# 00:05:9e:97:19:b0    230333
# c2:9f:db:97:5d:fe     96746
# 0a:18:d6:a9:64:7c     92131
# 28:80:23:32:16:16     82302
# c0:25:e9:7e:d8:5e     81838
# 28:80:23:32:16:10     77912
# 28:80:23:32:16:12     76393
# 28:80:23:32:16:11     75843
# 3c:a8:2a:78:d7:54     64302
# 2a:a4:3c:4d:a2:0e     58082
# 9c:8c:6e:40:bc:56     53285
# 3c:a8:2a:78:d7:51     42265
# 3c:a8:2a:78:d7:55     38563
# 3c:a8:2a:78:d7:50     33948
# 00:21:29:69:9a:02     31059
# c0:25:e9:7e:d8:5d     30942
# 00:18:39:87:10:99     20741
# dc:35:f1:34:58:37     18766
# 24:da:9b:8a:99:58     14905
# dc:bf:e9:d2:e2:f7     10486
# c0:8c:71:7a:83:d6     10427
# 5c:af:06:34:6b:97     10327
# 38:9a:f6:3e:95:af       599
# 0c:9d:92:23:d0:ab       599
# 30:cb:f8:39:66:d7       599
# 38:9a:f6:85:ad:c9       590
# 50:92:b9:cf:e4:06       584
# 38:9a:f6:88:51:c1       579
# 98:39:8e:98:f4:9b       577
# 28:83:35:f8:10:d3       574
# cc:61:e5:84:f7:82       574
# a8:96:75:6e:87:d3       569
# ...

# %%
data_test = pd.read_csv("domestic_TPS2.csv")

# %%
data_test
# Out:
#         Unnamed: 0  Unnamed: 0.1 Building      ClientMacAddr    Level  \
# 0               23           110     TPS2  c0:8c:71:70:f4:85  Level 3
# 1               27           126     TPS2  48:c7:96:88:7b:e9  Level 3
# 2               35           170     TPS2  60:ab:67:93:af:30  Level 3
# 3               51           254     TPS2  10:f1:f2:9a:67:5e  Level 3
# 4               59           302     TPS2  24:18:1d:c9:46:86  Level 3
# ...            ...           ...      ...                ...      ...
# 119500      443306       1849583     TPS2  70:fd:46:78:82:9a  Level 3
# 119501      443436       1850288     TPS2  30:07:4d:a4:e3:20  Level 3
# 119502      443440       1850310     TPS2  aa:16:d0:c5:f0:65  Level 3
# 119503      443441       1850311     TPS2  aa:16:d0:c5:f0:65  Level 3
# 119504      443455       1850386     TPS2  98:ca:33:dd:33:91  Level 3
#
#               lat        lng                localtime  \
# 0      -22.814361 -43.247444  2019-11-15 13:49:43.505
# ...

# %%
tps2_data = data_test.drop_duplicates(subset="ClientMacAddr", keep='first', inplace=False)

# %%
tps2_data
# Out:
#         Unnamed: 0  Unnamed: 0.1 Building      ClientMacAddr    Level  \
# 0               23           110     TPS2  c0:8c:71:70:f4:85  Level 3
# 1               27           126     TPS2  48:c7:96:88:7b:e9  Level 3
# 2               35           170     TPS2  60:ab:67:93:af:30  Level 3
# 3               51           254     TPS2  10:f1:f2:9a:67:5e  Level 3
# 4               59           302     TPS2  24:18:1d:c9:46:86  Level 3
# ...            ...           ...      ...                ...      ...
# 119422      439457       1830183     TPS2  30:07:4d:a4:e3:20  Level 3
# 119427      439644       1831029     TPS2  70:fd:46:48:e7:e8  Level 3
# 119451      440807       1836917     TPS2  fc:64:3a:be:81:be  Level 3
# 119480      442135       1843347     TPS2  80:58:f8:46:2b:4d  Level 3
# 119487      442620       1845985     TPS2  2c:59:8a:69:3a:6d  Level 3
#
#               lat        lng                localtime  \
# 0      -22.814361 -43.247444  2019-11-15 13:49:43.505
# ...

# %%
tps2_data_new = tps2_data[(tps2_data["waiting_time"] < 300)]

# %%
tps2_data_new
# Out:
#         Unnamed: 0  Unnamed: 0.1 Building      ClientMacAddr    Level  \
# 0               23           110     TPS2  c0:8c:71:70:f4:85  Level 3
# 1               27           126     TPS2  48:c7:96:88:7b:e9  Level 3
# 2               35           170     TPS2  60:ab:67:93:af:30  Level 3
# 3               51           254     TPS2  10:f1:f2:9a:67:5e  Level 3
# 4               59           302     TPS2  24:18:1d:c9:46:86  Level 3
# ...            ...           ...      ...                ...      ...
# 119422      439457       1830183     TPS2  30:07:4d:a4:e3:20  Level 3
# 119427      439644       1831029     TPS2  70:fd:46:48:e7:e8  Level 3
# 119451      440807       1836917     TPS2  fc:64:3a:be:81:be  Level 3
# 119480      442135       1843347     TPS2  80:58:f8:46:2b:4d  Level 3
# 119487      442620       1845985     TPS2  2c:59:8a:69:3a:6d  Level 3
#
#               lat        lng                localtime  \
# 0      -22.814361 -43.247444  2019-11-15 13:49:43.505
# ...

# %%
tps2_data_new.to_csv("domestic_TPS2_distinct.csv")
